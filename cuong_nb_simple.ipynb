# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    mean_absolute_error,
)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split

np.random.seed(42)
tf.random.set_seed(42)

# Check keras version
print(tf.__version__)
print(keras.__version__)

# %%
# ==========================================
# 1. DATA PREPARATION & NORMALIZATION
# ==========================================
# Load the dataset
try:
    with np.load("dataset_dev_3000.npz") as data:
        X_raw = data["X"]
        y_raw = data["y"]
    print(f"Dataset loaded successfully: X={X_raw.shape}, y={y_raw.shape}")
except FileNotFoundError:
    # Fallback for demonstration
    print("WARNING: 'dataset_dev_3000.npz' not found. Generating dummy data.")
    X_raw = np.random.uniform(0, 7, (3000, 32, 32)).astype("float32")
    y_raw = np.column_stack(
        [
            np.random.randint(0, 10, 3000),  # Target A
            np.random.randint(0, 32, 3000),  # Target B
            np.random.rand(3000),  # Target C
        ]
    ).astype("float32")

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_raw, y_raw, test_size=0.2, random_state=42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.2, random_state=42
)

print("--- 1. DATA PREPARATION ---")

# Calculate Global Max from Training Data
GLOBAL_MAX = float(X_train.max())
print(f"Global Max found in training data: {GLOBAL_MAX:.4f}")

# --- CRITICAL FIX: RESHAPE & NORMALIZE ---
# We must add the channel dimension: (N, 32, 32) -> (N, 32, 32, 1)
# AND normalize to [0, 1]
X_train_norm = X_train.reshape((-1, 32, 32, 1)).astype("float32") / GLOBAL_MAX
X_val_norm = X_val.reshape((-1, 32, 32, 1)).astype("float32") / GLOBAL_MAX
X_test_norm = X_test.reshape((-1, 32, 32, 1)).astype("float32") / GLOBAL_MAX

# Verify stats
print(f"Train Norm Shape: {X_train_norm.shape} (Must be Rank-4)")
print(f"Train Norm Range: [{X_train_norm.min():.3f}, {X_train_norm.max():.3f}]")

# Split Targets
y_train_A = y_train[:, 0]
y_train_B = y_train[:, 1]
y_train_C = y_train[:, 2]

y_val_A = y_val[:, 0]
y_val_B = y_val[:, 1]
y_val_C = y_val[:, 2]

y_test_A = y_test[:, 0]
y_test_B = y_test[:, 1]
y_test_C = y_test[:, 2]

# %%
# ==========================================
# 2. MODEL ARCHITECTURE
# ==========================================
# Clear TF/Keras global state so re-running this cell rebuilds a *fresh* model.
# (This does NOT reset an already-created model; it prevents graph/state buildup.)
keras.backend.clear_session()

print("\n--- 2. BUILDING MODEL ---")


def build_model():
    inputs = keras.Input(shape=(32, 32, 1), name="img_input")

    # --- A. Data Augmentation ---
    x = layers.RandomFlip("horizontal")(inputs)
    x = layers.RandomRotation(0.1)(x)
    x = layers.RandomZoom(0.1)(x)

    # --- B. The Trunk ---
    # Block 1
    x = layers.Conv2D(32, 3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D(2)(x)

    # Block 2
    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D(2)(x)

    # Block 3
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.MaxPooling2D(2)(x)

    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)

    features = layers.Dense(128, activation="relu")(x)

    # --- C. The Specialized Heads ---
    # Head A (0-9)
    branch_a = layers.Dense(64, activation="relu")(features)
    out_a = layers.Dense(10, activation="softmax", name="out_a")(branch_a)

    # Head B (0-31)
    branch_b = layers.Dense(64, activation="relu")(features)
    out_b = layers.Dense(32, activation="softmax", name="out_b")(branch_b)

    # Head C (Regression)
    branch_c = layers.Dense(32, activation="relu")(features)
    out_c = layers.Dense(1, activation="sigmoid", name="out_c")(branch_c)

    model = keras.Model(inputs=inputs, outputs=[out_a, out_b, out_c])
    return model


model = build_model()
model.summary()
# Out:
# --- 2. BUILDING MODEL ---
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ img_input           │ (None, 32, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_flip         │ (None, 32, 32, 1) │          0 │ img_input[0][0]   │
# │ (RandomFlip)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation     │ (None, 32, 32, 1) │          0 │ random_flip[0][0] │
# │ (RandomRotation)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_zoom         │ (None, 32, 32, 1) │          0 │ random_rotation[… │
# │ (RandomZoom)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        320 │ random_zoom[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 8, 8, 64)  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 8, 8, 128) │     73,856 │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 4, 4, 128) │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 2048)      │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    262,272 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      8,256 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │      4,128 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_a (Dense)       │ (None, 10)        │        650 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_b (Dense)       │ (None, 32)        │      2,080 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_c (Dense)       │ (None, 1)         │         33 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 378,347 (1.44 MB)
#  Trainable params: 378,347 (1.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ==========================================
# 3. COMPILATION
# ==========================================
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss={
        "out_a": "sparse_categorical_crossentropy",
        "out_b": "sparse_categorical_crossentropy",
        "out_c": "mse",
    },
    loss_weights=[1.0, 1.0, 5.0],
    metrics={"out_a": "accuracy", "out_b": "accuracy", "out_c": "mae"},
)

# %%
# ==========================================
# 4. TRAINING
# ==========================================
print("\n--- 3. STARTING TRAINING ---")

callbacks = [
    # If LR is small, progress per epoch can be slow/noisy; let it run longer and
    # optionally auto-reduce LR on plateaus before we give up.
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        verbose=1,
        min_lr=1e-4,
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=20,
        restore_best_weights=True,
        verbose=1,
    ),
]

history = model.fit(
    X_train_norm,
    [y_train_A, y_train_B, y_train_C],
    epochs=50,
    batch_size=32,
    validation_data=(X_val_norm, [y_val_A, y_val_B, y_val_C]),
    callbacks=callbacks,
    verbose=1,
)
# Out:
# --- 3. STARTING TRAINING ---
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 6.1799 - out_a_accuracy: 0.0897 - out_a_loss: 2.3039 - out_b_accuracy: 0.0232 - out_b_loss: 3.4690 - out_c_loss: 0.0814 - out_c_mae: 0.2465 - val_loss: 6.1274 - val_out_a_accuracy: 0.1083 - val_out_a_loss: 2.3030 - val_out_b_accuracy: 0.0271 - val_out_b_loss: 3.4691 - val_out_c_loss: 0.0711 - val_out_c_mae: 0.2287 - learning_rate: 0.0010
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0938 - out_a_accuracy: 0.1136 - out_a_loss: 2.2912 - out_b_accuracy: 0.0404 - out_b_loss: 3.4636 - out_c_loss: 0.0678 - out_c_mae: 0.2171 - val_loss: 6.0540 - val_out_a_accuracy: 0.1458 - val_out_a_loss: 2.2607 - val_out_b_accuracy: 0.0250 - val_out_b_loss: 3.4771 - val_out_c_loss: 0.0632 - val_out_c_mae: 0.2078 - learning_rate: 0.0010
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0069 - out_a_accuracy: 0.1356 - out_a_loss: 2.2568 - out_b_accuracy: 0.0454 - out_b_loss: 3.4550 - out_c_loss: 0.0590 - out_c_mae: 0.1990 - val_loss: 6.0662 - val_out_a_accuracy: 0.1562 - val_out_a_loss: 2.2550 - val_out_b_accuracy: 0.0250 - val_out_b_loss: 3.4778 - val_out_c_loss: 0.0667 - val_out_c_mae: 0.2163 - learning_rate: 0.0010
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9650 - out_a_accuracy: 0.1454 - out_a_loss: 2.2407 - out_b_accuracy: 0.0540 - out_b_loss: 3.4477 - out_c_loss: 0.0553 - out_c_mae: 0.1923 - val_loss: 6.1171 - val_out_a_accuracy: 0.1250 - val_out_a_loss: 2.2871 - val_out_b_accuracy: 0.0271 - val_out_b_loss: 3.4887 - val_out_c_loss: 0.0683 - val_out_c_mae: 0.2079 - learning_rate: 0.0010
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9914 - out_a_accuracy: 0.1314 - out_a_loss: 2.2486 - out_b_accuracy: 0.0537 - out_b_loss: 3.4399 - out_c_loss: 0.0606 - out_c_mae: 0.2021 - val_loss: 5.9817 - val_out_a_accuracy: 0.1437 - val_out_a_loss: 2.2198 - val_out_b_accuracy: 0.0250 - val_out_b_loss: 3.4725 - val_out_c_loss: 0.0579 - val_out_c_mae: 0.1980 - learning_rate: 0.0010
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.9551 - out_a_accuracy: 0.1559 - out_a_loss: 2.2289 - out_b_accuracy: 0.0425 - out_b_loss: 3.4338 - out_c_loss: 0.0585 - out_c_mae: 0.1994 - val_loss: 6.0031 - val_out_a_accuracy: 0.1688 - val_out_a_loss: 2.2095 - val_out_b_accuracy: 0.0208 - val_out_b_loss: 3.4694 - val_out_c_loss: 0.0648 - val_out_c_mae: 0.2137 - learning_rate: 0.0010
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9303 - out_a_accuracy: 0.1644 - out_a_loss: 2.2026 - out_b_accuracy: 0.0473 - out_b_loss: 3.4391 - out_c_loss: 0.0577 - out_c_mae: 0.1972 - val_loss: 5.9179 - val_out_a_accuracy: 0.1875 - val_out_a_loss: 2.1594 - val_out_b_accuracy: 0.0271 - val_out_b_loss: 3.4687 - val_out_c_loss: 0.0580 - val_out_c_mae: 0.1998 - learning_rate: 0.0010
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8956 - out_a_accuracy: 0.1761 - out_a_loss: 2.1756 - out_b_accuracy: 0.0469 - out_b_loss: 3.4353 - out_c_loss: 0.0569 - out_c_mae: 0.1946 - val_loss: 5.8634 - val_out_a_accuracy: 0.2208 - val_out_a_loss: 2.1406 - val_out_b_accuracy: 0.0312 - val_out_b_loss: 3.4583 - val_out_c_loss: 0.0529 - val_out_c_mae: 0.1861 - learning_rate: 0.0010
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8228 - out_a_accuracy: 0.2202 - out_a_loss: 2.1340 - out_b_accuracy: 0.0607 - out_b_loss: 3.4134 - out_c_loss: 0.0551 - out_c_mae: 0.1909 - val_loss: 5.7639 - val_out_a_accuracy: 0.2354 - val_out_a_loss: 2.0732 - val_out_b_accuracy: 0.0250 - val_out_b_loss: 3.4564 - val_out_c_loss: 0.0469 - val_out_c_mae: 0.1766 - learning_rate: 0.0010
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7880 - out_a_accuracy: 0.2345 - out_a_loss: 2.1064 - out_b_accuracy: 0.0537 - out_b_loss: 3.4158 - out_c_loss: 0.0532 - out_c_mae: 0.1888 - val_loss: 5.7920 - val_out_a_accuracy: 0.2021 - val_out_a_loss: 2.1046 - val_out_b_accuracy: 0.0208 - val_out_b_loss: 3.4564 - val_out_c_loss: 0.0462 - val_out_c_mae: 0.1729 - learning_rate: 0.0010
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7775 - out_a_accuracy: 0.2354 - out_a_loss: 2.0994 - out_b_accuracy: 0.0549 - out_b_loss: 3.4095 - out_c_loss: 0.0537 - out_c_mae: 0.1869 - val_loss: 5.6784 - val_out_a_accuracy: 0.2458 - val_out_a_loss: 2.0097 - val_out_b_accuracy: 0.0333 - val_out_b_loss: 3.4381 - val_out_c_loss: 0.0461 - val_out_c_mae: 0.1776 - learning_rate: 0.0010
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7062 - out_a_accuracy: 0.2672 - out_a_loss: 2.0528 - out_b_accuracy: 0.0576 - out_b_loss: 3.3955 - out_c_loss: 0.0516 - out_c_mae: 0.1831 - val_loss: 5.6735 - val_out_a_accuracy: 0.2375 - val_out_a_loss: 2.0426 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3878 - val_out_c_loss: 0.0486 - val_out_c_mae: 0.1783 - learning_rate: 0.0010
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.6305 - out_a_accuracy: 0.2707 - out_a_loss: 2.0242 - out_b_accuracy: 0.0618 - out_b_loss: 3.3648 - out_c_loss: 0.0483 - out_c_mae: 0.1762 - val_loss: 5.6034 - val_out_a_accuracy: 0.2521 - val_out_a_loss: 2.0101 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3560 - val_out_c_loss: 0.0475 - val_out_c_mae: 0.1783 - learning_rate: 0.0010
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5966 - out_a_accuracy: 0.2966 - out_a_loss: 2.0092 - out_b_accuracy: 0.0771 - out_b_loss: 3.3392 - out_c_loss: 0.0496 - out_c_mae: 0.1807 - val_loss: 5.5642 - val_out_a_accuracy: 0.2583 - val_out_a_loss: 2.0223 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3306 - val_out_c_loss: 0.0423 - val_out_c_mae: 0.1674 - learning_rate: 0.0010
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.5374 - out_a_accuracy: 0.2922 - out_a_loss: 1.9650 - out_b_accuracy: 0.0720 - out_b_loss: 3.3394 - out_c_loss: 0.0466 - out_c_mae: 0.1749 - val_loss: 5.6124 - val_out_a_accuracy: 0.2417 - val_out_a_loss: 2.0698 - val_out_b_accuracy: 0.0458 - val_out_b_loss: 3.3349 - val_out_c_loss: 0.0415 - val_out_c_mae: 0.1628 - learning_rate: 0.0010
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5659 - out_a_accuracy: 0.2820 - out_a_loss: 2.0034 - out_b_accuracy: 0.0698 - out_b_loss: 3.3268 - out_c_loss: 0.0471 - out_c_mae: 0.1744 - val_loss: 5.5362 - val_out_a_accuracy: 0.2521 - val_out_a_loss: 2.0127 - val_out_b_accuracy: 0.0458 - val_out_b_loss: 3.3142 - val_out_c_loss: 0.0418 - val_out_c_mae: 0.1631 - learning_rate: 0.0010
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4858 - out_a_accuracy: 0.3049 - out_a_loss: 1.9414 - out_b_accuracy: 0.0743 - out_b_loss: 3.3043 - out_c_loss: 0.0480 - out_c_mae: 0.1762 - val_loss: 5.5042 - val_out_a_accuracy: 0.2896 - val_out_a_loss: 1.9759 - val_out_b_accuracy: 0.0458 - val_out_b_loss: 3.3192 - val_out_c_loss: 0.0418 - val_out_c_mae: 0.1665 - learning_rate: 0.0010
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.5072 - out_a_accuracy: 0.2783 - out_a_loss: 1.9623 - out_b_accuracy: 0.0642 - out_b_loss: 3.2889 - out_c_loss: 0.0512 - out_c_mae: 0.1841 - val_loss: 5.5223 - val_out_a_accuracy: 0.2688 - val_out_a_loss: 2.0020 - val_out_b_accuracy: 0.0333 - val_out_b_loss: 3.3245 - val_out_c_loss: 0.0391 - val_out_c_mae: 0.1569 - learning_rate: 0.0010
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4493 - out_a_accuracy: 0.2892 - out_a_loss: 1.9555 - out_b_accuracy: 0.0808 - out_b_loss: 3.2689 - out_c_loss: 0.0450 - out_c_mae: 0.1699 - val_loss: 5.5183 - val_out_a_accuracy: 0.2750 - val_out_a_loss: 1.9912 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3341 - val_out_c_loss: 0.0386 - val_out_c_mae: 0.1554 - learning_rate: 0.0010
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4355 - out_a_accuracy: 0.3087 - out_a_loss: 1.9116 - out_b_accuracy: 0.0909 - out_b_loss: 3.2812 - out_c_loss: 0.0486 - out_c_mae: 0.1753 - val_loss: 5.4310 - val_out_a_accuracy: 0.3167 - val_out_a_loss: 1.9377 - val_out_b_accuracy: 0.0479 - val_out_b_loss: 3.2957 - val_out_c_loss: 0.0395 - val_out_c_mae: 0.1600 - learning_rate: 0.0010
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4639 - out_a_accuracy: 0.3021 - out_a_loss: 1.9420 - out_b_accuracy: 0.0671 - out_b_loss: 3.2758 - out_c_loss: 0.0492 - out_c_mae: 0.1765 - val_loss: 5.5716 - val_out_a_accuracy: 0.2521 - val_out_a_loss: 2.0418 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3115 - val_out_c_loss: 0.0437 - val_out_c_mae: 0.1688 - learning_rate: 0.0010
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3827 - out_a_accuracy: 0.3208 - out_a_loss: 1.8914 - out_b_accuracy: 0.0829 - out_b_loss: 3.2686 - out_c_loss: 0.0445 - out_c_mae: 0.1681 - val_loss: 5.4762 - val_out_a_accuracy: 0.3021 - val_out_a_loss: 1.9398 - val_out_b_accuracy: 0.0521 - val_out_b_loss: 3.3042 - val_out_c_loss: 0.0465 - val_out_c_mae: 0.1760 - learning_rate: 0.0010
# Epoch 23/50
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3124 - out_a_accuracy: 0.3431 - out_a_loss: 1.8451 - out_b_accuracy: 0.0719 - out_b_loss: 3.2484 - out_c_loss: 0.0438 - out_c_mae: 0.1676
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3174 - out_a_accuracy: 0.3417 - out_a_loss: 1.8484 - out_b_accuracy: 0.0714 - out_b_loss: 3.2498 - out_c_loss: 0.0439 - out_c_mae: 0.1678 - val_loss: 5.4752 - val_out_a_accuracy: 0.2792 - val_out_a_loss: 1.9633 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3107 - val_out_c_loss: 0.0402 - val_out_c_mae: 0.1545 - learning_rate: 0.0010
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2823 - out_a_accuracy: 0.3476 - out_a_loss: 1.8245 - out_b_accuracy: 0.0828 - out_b_loss: 3.2337 - out_c_loss: 0.0448 - out_c_mae: 0.1645 - val_loss: 5.4344 - val_out_a_accuracy: 0.3375 - val_out_a_loss: 1.9182 - val_out_b_accuracy: 0.0333 - val_out_b_loss: 3.3297 - val_out_c_loss: 0.0373 - val_out_c_mae: 0.1510 - learning_rate: 5.0000e-04
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2791 - out_a_accuracy: 0.3425 - out_a_loss: 1.8346 - out_b_accuracy: 0.0868 - out_b_loss: 3.2285 - out_c_loss: 0.0432 - out_c_mae: 0.1643 - val_loss: 5.4576 - val_out_a_accuracy: 0.2937 - val_out_a_loss: 1.9596 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3126 - val_out_c_loss: 0.0371 - val_out_c_mae: 0.1524 - learning_rate: 5.0000e-04
# Epoch 26/50
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2678 - out_a_accuracy: 0.3343 - out_a_loss: 1.8346 - out_b_accuracy: 0.0910 - out_b_loss: 3.2222 - out_c_loss: 0.0422 - out_c_mae: 0.1630
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2689 - out_a_accuracy: 0.3343 - out_a_loss: 1.8354 - out_b_accuracy: 0.0906 - out_b_loss: 3.2223 - out_c_loss: 0.0423 - out_c_mae: 0.1631 - val_loss: 5.4609 - val_out_a_accuracy: 0.3292 - val_out_a_loss: 1.9469 - val_out_b_accuracy: 0.0458 - val_out_b_loss: 3.3280 - val_out_c_loss: 0.0372 - val_out_c_mae: 0.1508 - learning_rate: 5.0000e-04
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2689 - out_a_accuracy: 0.3380 - out_a_loss: 1.8287 - out_b_accuracy: 0.0944 - out_b_loss: 3.2225 - out_c_loss: 0.0436 - out_c_mae: 0.1647 - val_loss: 5.4150 - val_out_a_accuracy: 0.3354 - val_out_a_loss: 1.9163 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3151 - val_out_c_loss: 0.0367 - val_out_c_mae: 0.1515 - learning_rate: 2.5000e-04
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2604 - out_a_accuracy: 0.3296 - out_a_loss: 1.8366 - out_b_accuracy: 0.0888 - out_b_loss: 3.2121 - out_c_loss: 0.0423 - out_c_mae: 0.1627 - val_loss: 5.4404 - val_out_a_accuracy: 0.3125 - val_out_a_loss: 1.9322 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3251 - val_out_c_loss: 0.0366 - val_out_c_mae: 0.1495 - learning_rate: 2.5000e-04
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2588 - out_a_accuracy: 0.3258 - out_a_loss: 1.8285 - out_b_accuracy: 0.0805 - out_b_loss: 3.2145 - out_c_loss: 0.0432 - out_c_mae: 0.1642 - val_loss: 5.4317 - val_out_a_accuracy: 0.3167 - val_out_a_loss: 1.9326 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3167 - val_out_c_loss: 0.0365 - val_out_c_mae: 0.1511 - learning_rate: 2.5000e-04
# Epoch 30/50
# 57/60 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2578 - out_a_accuracy: 0.3392 - out_a_loss: 1.8095 - out_b_accuracy: 0.0928 - out_b_loss: 3.2323 - out_c_loss: 0.0432 - out_c_mae: 0.1662
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2567 - out_a_accuracy: 0.3395 - out_a_loss: 1.8094 - out_b_accuracy: 0.0922 - out_b_loss: 3.2318 - out_c_loss: 0.0431 - out_c_mae: 0.1659 - val_loss: 5.4274 - val_out_a_accuracy: 0.3354 - val_out_a_loss: 1.9216 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3215 - val_out_c_loss: 0.0369 - val_out_c_mae: 0.1521 - learning_rate: 2.5000e-04
# Epoch 31/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2138 - out_a_accuracy: 0.3412 - out_a_loss: 1.7919 - out_b_accuracy: 0.0869 - out_b_loss: 3.2148 - out_c_loss: 0.0414 - out_c_mae: 0.1597 - val_loss: 5.4198 - val_out_a_accuracy: 0.3458 - val_out_a_loss: 1.9162 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3241 - val_out_c_loss: 0.0359 - val_out_c_mae: 0.1488 - learning_rate: 1.2500e-04
# Epoch 32/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1282 - out_a_accuracy: 0.3827 - out_a_loss: 1.7572 - out_b_accuracy: 0.1011 - out_b_loss: 3.1638 - out_c_loss: 0.0415 - out_c_mae: 0.1608 - val_loss: 5.4231 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9145 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3290 - val_out_c_loss: 0.0359 - val_out_c_mae: 0.1492 - learning_rate: 1.2500e-04
# Epoch 33/50
# 58/60 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2389 - out_a_accuracy: 0.3458 - out_a_loss: 1.7947 - out_b_accuracy: 0.1003 - out_b_loss: 3.2136 - out_c_loss: 0.0461 - out_c_mae: 0.1699
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001.
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2372 - out_a_accuracy: 0.3457 - out_a_loss: 1.7948 - out_b_accuracy: 0.1000 - out_b_loss: 3.2128 - out_c_loss: 0.0459 - out_c_mae: 0.1695 - val_loss: 5.4169 - val_out_a_accuracy: 0.3438 - val_out_a_loss: 1.9120 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3251 - val_out_c_loss: 0.0360 - val_out_c_mae: 0.1491 - learning_rate: 1.2500e-04
# Epoch 34/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1963 - out_a_accuracy: 0.3413 - out_a_loss: 1.8235 - out_b_accuracy: 0.0999 - out_b_loss: 3.1730 - out_c_loss: 0.0400 - out_c_mae: 0.1589 - val_loss: 5.4254 - val_out_a_accuracy: 0.3458 - val_out_a_loss: 1.9184 - val_out_b_accuracy: 0.0354 - val_out_b_loss: 3.3305 - val_out_c_loss: 0.0353 - val_out_c_mae: 0.1469 - learning_rate: 1.0000e-04
# Epoch 35/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1809 - out_a_accuracy: 0.3630 - out_a_loss: 1.7800 - out_b_accuracy: 0.0979 - out_b_loss: 3.1871 - out_c_loss: 0.0428 - out_c_mae: 0.1636 - val_loss: 5.4244 - val_out_a_accuracy: 0.3438 - val_out_a_loss: 1.9156 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3315 - val_out_c_loss: 0.0355 - val_out_c_mae: 0.1473 - learning_rate: 1.0000e-04
# Epoch 36/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1996 - out_a_accuracy: 0.3502 - out_a_loss: 1.8019 - out_b_accuracy: 0.0958 - out_b_loss: 3.1892 - out_c_loss: 0.0417 - out_c_mae: 0.1629 - val_loss: 5.4133 - val_out_a_accuracy: 0.3396 - val_out_a_loss: 1.9127 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3236 - val_out_c_loss: 0.0354 - val_out_c_mae: 0.1476 - learning_rate: 1.0000e-04
# Epoch 37/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1445 - out_a_accuracy: 0.3740 - out_a_loss: 1.7613 - out_b_accuracy: 0.0918 - out_b_loss: 3.1760 - out_c_loss: 0.0415 - out_c_mae: 0.1603 - val_loss: 5.4225 - val_out_a_accuracy: 0.3500 - val_out_a_loss: 1.9161 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3294 - val_out_c_loss: 0.0354 - val_out_c_mae: 0.1473 - learning_rate: 1.0000e-04
# Epoch 38/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2149 - out_a_accuracy: 0.3454 - out_a_loss: 1.8049 - out_b_accuracy: 0.0999 - out_b_loss: 3.1956 - out_c_loss: 0.0429 - out_c_mae: 0.1654 - val_loss: 5.4223 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9186 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3279 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1471 - learning_rate: 1.0000e-04
# Epoch 39/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2128 - out_a_accuracy: 0.3518 - out_a_loss: 1.7936 - out_b_accuracy: 0.0921 - out_b_loss: 3.2047 - out_c_loss: 0.0429 - out_c_mae: 0.1640 - val_loss: 5.4282 - val_out_a_accuracy: 0.3479 - val_out_a_loss: 1.9217 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3306 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1464 - learning_rate: 1.0000e-04
# Epoch 40/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2187 - out_a_accuracy: 0.3479 - out_a_loss: 1.7993 - out_b_accuracy: 0.0808 - out_b_loss: 3.2100 - out_c_loss: 0.0419 - out_c_mae: 0.1610 - val_loss: 5.4256 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9187 - val_out_b_accuracy: 0.0437 - val_out_b_loss: 3.3306 - val_out_c_loss: 0.0353 - val_out_c_mae: 0.1465 - learning_rate: 1.0000e-04
# Epoch 41/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1410 - out_a_accuracy: 0.3475 - out_a_loss: 1.7855 - out_b_accuracy: 0.0909 - out_b_loss: 3.1603 - out_c_loss: 0.0391 - out_c_mae: 0.1567 - val_loss: 5.4284 - val_out_a_accuracy: 0.3458 - val_out_a_loss: 1.9214 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3299 - val_out_c_loss: 0.0354 - val_out_c_mae: 0.1473 - learning_rate: 1.0000e-04
# Epoch 42/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1926 - out_a_accuracy: 0.3548 - out_a_loss: 1.7945 - out_b_accuracy: 0.0854 - out_b_loss: 3.1936 - out_c_loss: 0.0409 - out_c_mae: 0.1614 - val_loss: 5.4299 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9225 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3320 - val_out_c_loss: 0.0351 - val_out_c_mae: 0.1468 - learning_rate: 1.0000e-04
# Epoch 43/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1791 - out_a_accuracy: 0.3677 - out_a_loss: 1.7519 - out_b_accuracy: 0.0843 - out_b_loss: 3.2183 - out_c_loss: 0.0418 - out_c_mae: 0.1598 - val_loss: 5.4309 - val_out_a_accuracy: 0.3354 - val_out_a_loss: 1.9229 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3321 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1464 - learning_rate: 1.0000e-04
# Epoch 44/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2120 - out_a_accuracy: 0.3528 - out_a_loss: 1.7944 - out_b_accuracy: 0.0841 - out_b_loss: 3.2071 - out_c_loss: 0.0421 - out_c_mae: 0.1612 - val_loss: 5.4300 - val_out_a_accuracy: 0.3438 - val_out_a_loss: 1.9243 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3298 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1477 - learning_rate: 1.0000e-04
# Epoch 45/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1530 - out_a_accuracy: 0.3649 - out_a_loss: 1.7805 - out_b_accuracy: 0.1032 - out_b_loss: 3.1684 - out_c_loss: 0.0408 - out_c_mae: 0.1612 - val_loss: 5.4388 - val_out_a_accuracy: 0.3458 - val_out_a_loss: 1.9257 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3370 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1461 - learning_rate: 1.0000e-04
# Epoch 46/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1616 - out_a_accuracy: 0.3627 - out_a_loss: 1.7582 - out_b_accuracy: 0.0930 - out_b_loss: 3.1951 - out_c_loss: 0.0417 - out_c_mae: 0.1618 - val_loss: 5.4309 - val_out_a_accuracy: 0.3500 - val_out_a_loss: 1.9229 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3330 - val_out_c_loss: 0.0350 - val_out_c_mae: 0.1466 - learning_rate: 1.0000e-04
# Epoch 47/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1879 - out_a_accuracy: 0.3540 - out_a_loss: 1.7993 - out_b_accuracy: 0.0856 - out_b_loss: 3.1863 - out_c_loss: 0.0405 - out_c_mae: 0.1603 - val_loss: 5.4411 - val_out_a_accuracy: 0.3458 - val_out_a_loss: 1.9267 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3391 - val_out_c_loss: 0.0351 - val_out_c_mae: 0.1461 - learning_rate: 1.0000e-04
# Epoch 48/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1610 - out_a_accuracy: 0.3651 - out_a_loss: 1.7663 - out_b_accuracy: 0.0902 - out_b_loss: 3.1807 - out_c_loss: 0.0428 - out_c_mae: 0.1640 - val_loss: 5.4341 - val_out_a_accuracy: 0.3438 - val_out_a_loss: 1.9195 - val_out_b_accuracy: 0.0396 - val_out_b_loss: 3.3350 - val_out_c_loss: 0.0359 - val_out_c_mae: 0.1475 - learning_rate: 1.0000e-04
# Epoch 49/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1216 - out_a_accuracy: 0.3687 - out_a_loss: 1.7425 - out_b_accuracy: 0.0955 - out_b_loss: 3.1805 - out_c_loss: 0.0397 - out_c_mae: 0.1578 - val_loss: 5.4410 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9235 - val_out_b_accuracy: 0.0375 - val_out_b_loss: 3.3388 - val_out_c_loss: 0.0357 - val_out_c_mae: 0.1476 - learning_rate: 1.0000e-04
# Epoch 50/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1723 - out_a_accuracy: 0.3671 - out_a_loss: 1.7659 - out_b_accuracy: 0.1019 - out_b_loss: 3.1846 - out_c_loss: 0.0444 - out_c_mae: 0.1661 - val_loss: 5.4266 - val_out_a_accuracy: 0.3417 - val_out_a_loss: 1.9159 - val_out_b_accuracy: 0.0417 - val_out_b_loss: 3.3345 - val_out_c_loss: 0.0352 - val_out_c_mae: 0.1467 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 36.

# %%
# Plot the history
hist = history.history

# Plot all tracked series (train vs val) in a grid.
base_keys = [k for k in hist.keys() if not k.startswith("val_")]

# Prefer a stable, readable ordering
preferred_order = [
    "loss",
    "out_a_loss",
    "out_b_loss",
    "out_c_loss",
    "out_a_accuracy",
    "out_b_accuracy",
    "out_c_mae",
]

ordered = [k for k in preferred_order if k in base_keys] + [
    k for k in base_keys if k not in preferred_order
]

n = len(ordered)
if n == 0:
    raise ValueError("history.history is empty; did model.fit() run?")

ncols = 2 if n > 1 else 1
nrows = int(np.ceil(n / ncols))

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 4 * nrows))
axes = np.array(axes).reshape(-1)

epochs = np.arange(1, len(hist[ordered[0]]) + 1)

for i, key in enumerate(ordered):
    ax = axes[i]
    ax.plot(epochs, hist[key], label=f"train/{key}")

    vkey = f"val_{key}"
    if vkey in hist:
        ax.plot(epochs, hist[vkey], label=f"val/{key}")

    ax.set_title(key)
    ax.set_xlabel("epoch")
    ax.grid(True, alpha=0.3)
    ax.legend()

# Hide any unused axes
for j in range(i + 1, len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

# %%
# ==========================================
# 5. PREDICT FUNCTION
# ==========================================
def predict_fn(X_raw):
    # 1. Reshape
    # 2. Normalize
    X_proc = X_raw.reshape((-1, 32, 32, 1)).astype("float32") / GLOBAL_MAX

    # 3. Predict
    pred_probs_a, pred_probs_b, pred_c_val = model.predict(X_proc, verbose=0)

    # 4. Process
    pred_a = np.argmax(pred_probs_a, axis=1)
    pred_b = np.argmax(pred_probs_b, axis=1)
    pred_c = pred_c_val.flatten()

    # 5. Stack
    return np.column_stack([pred_a, pred_b, pred_c])


print("\n--- CHECKING PREDICT_FN ---")
sample_preds = predict_fn(X_val[:5])
print("Output Shape:", sample_preds.shape)
print("Sample Predictions:\n", sample_preds)
# Out:
# --- CHECKING PREDICT_FN ---
# Output Shape: (5, 3)
# Sample Predictions:
#  [[ 4.         29.          0.51041943]
#  [ 9.          9.          0.12885199]
#  [ 7.         13.          0.29688317]
#  [ 9.         13.          0.67390442]
#  [ 5.          3.          0.65437204]]

# %%
# ==========================================
# 6. EVALUATION & VISUALIZATION
# ==========================================
print("\n--- 4. EVALUATION & PLOTS ---")

# 1. Generate Predictions on Test Set
# We use the predict_fn wrapper which handles shaping/normalization automatically
print("Generating predictions for Test Set...")
val_preds = predict_fn(X_test)

# Extract components from the stacked predictions
# pred_a/b are class indices (integers), pred_c is float
pred_a = val_preds[:, 0].astype(int)
pred_b = val_preds[:, 1].astype(int)
pred_c = val_preds[:, 2]

# --- Target A (Classification 0-9) ---
print("\n" + "=" * 40)
print("TARGET A (Digits 0-9) PERFORMANCE")
print("=" * 40)
print(classification_report(y_test_A, pred_a))

# Plot Confusion Matrix for A
fig_a, ax_a = plt.subplots(figsize=(8, 8))
cm_a = confusion_matrix(y_test_A, pred_a)
disp_a = ConfusionMatrixDisplay(confusion_matrix=cm_a, display_labels=np.arange(10))
disp_a.plot(cmap=plt.cm.Blues, ax=ax_a)
ax_a.set_title("Target A: Confusion Matrix")
plt.show()

# --- Target B (Classification 0-31) ---
print("\n" + "=" * 40)
print("TARGET B (Classes 0-31) PERFORMANCE")
print("=" * 40)
# Note: Zero_division=0 handles classes that might not appear in validation set
print(classification_report(y_test_B, pred_b, zero_division=0))

# Plot Confusion Matrix for B
fig_b, ax_b = plt.subplots(figsize=(12, 12))
cm_b = confusion_matrix(y_test_B, pred_b)
# We don't list all 32 labels on axis to keep it clean, or we can just use default ints
disp_b = ConfusionMatrixDisplay(confusion_matrix=cm_b)
disp_b.plot(cmap=plt.cm.Greens, ax=ax_b, values_format="d")  # 'd' for integers
ax_b.set_title("Target B: Confusion Matrix")
plt.show()

# --- Target C (Regression 0-1) ---
print("\n" + "=" * 40)
print("TARGET C (Regression) PERFORMANCE")
print("=" * 40)
mae_c = mean_absolute_error(y_test_C, pred_c)
print(f"Mean Absolute Error (MAE): {mae_c:.4f}")

# Plot True vs Predicted
plt.figure(figsize=(8, 8))
plt.scatter(y_test_C, pred_c, alpha=0.5, color="purple", label="Predictions")
plt.plot([0, 1], [0, 1], "r--", linewidth=2, label="Ideal Perfect Prediction")
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title(f"Target C: True vs Predicted (MAE={mae_c:.4f})")
plt.legend()
plt.grid(True, alpha=0.3)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.show()
# Out:
# --- 4. EVALUATION & PLOTS ---
# Generating predictions for Test Set...
#
# ========================================
# TARGET A (Digits 0-9) PERFORMANCE
# ========================================
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.25      0.31        53
#          1.0       0.31      0.38      0.34        66
#          2.0       0.29      0.30      0.29        50
#          3.0       0.25      0.24      0.24        55
#          4.0       0.47      0.27      0.34        67
#          5.0       0.33      0.41      0.37        56
#          6.0       0.34      0.35      0.34        60
#          7.0       0.38      0.35      0.37        74
#          8.0       0.27      0.30      0.28        54
#          9.0       0.29      0.38      0.33        65
#
#     accuracy                           0.33       600
#    macro avg       0.34      0.32      0.32       600
# weighted avg       0.34      0.33      0.32       600
# ========================================
# TARGET B (Classes 0-31) PERFORMANCE
# ========================================
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.04      0.08        23
#          1.0       0.00      0.00      0.00        28
#          2.0       0.00      0.00      0.00        13
#          3.0       0.07      0.32      0.11        22
#          4.0       0.00      0.00      0.00        17
#          5.0       0.07      0.06      0.06        18
#          6.0       0.00      0.00      0.00        12
#          7.0       0.00      0.00      0.00        22
#          8.0       0.00      0.00      0.00        18
#          9.0       0.00      0.00      0.00        15
#         10.0       0.00      0.00      0.00        15
#         11.0       0.07      0.09      0.08        11
#         12.0       0.00      0.00      0.00        27
#         13.0       0.03      0.60      0.06        10
#         14.0       0.00      0.00      0.00        14
#         15.0       0.00      0.00      0.00        22
#         16.0       0.00      0.00      0.00        19
#         17.0       0.00      0.00      0.00        20
#         18.0       0.00      0.00      0.00        28
#         19.0       0.00      0.00      0.00        25
#         20.0       0.00      0.00      0.00        15
#         21.0       0.00      0.00      0.00        20
#         22.0       0.18      0.12      0.14        17
#         23.0       0.00      0.00      0.00        20
#         24.0       0.00      0.00      0.00        13
#         25.0       0.00      0.00      0.00        20
#         26.0       0.00      0.00      0.00        22
#         27.0       0.06      0.05      0.05        22
#         28.0       0.00      0.00      0.00        20
#         29.0       0.00      0.00      0.00        13
#         30.0       0.00      0.00      0.00        22
#         31.0       0.23      0.41      0.30        17
#
#     accuracy                           0.04       600
#    macro avg       0.03      0.05      0.03       600
# weighted avg       0.03      0.04      0.03       600
# ========================================
# TARGET C (Regression) PERFORMANCE
# ========================================
# Mean Absolute Error (MAE): 0.1461
